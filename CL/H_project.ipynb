# %% [markdown]
# <a href="https://colab.research.google.com/github/Uliana-san/Japan/blob/master/H_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip3 install requests # импортируем модуль requests

# %%
! pip3 install beautifulsoup4

# %%
import requests as rq

from bs4 import BeautifulSoup
import re

# %%
ria_hiroshima = 'https://ria.ru/search/?query=%D1%85%D0%B8%D1%80%D0%BE%D1%81%D0%B8%D0%BC%D0%B0'

# %%
ria_nagasaki = 'https://ria.ru/search/?query=%D0%BD%D0%B0%D0%B3%D0%B0%D1%81%D0%B0%D0%BA%D0%B8'

# %%
ria_page1 = rq.get(ria_hiroshima)
ria_page1
# Out:
# <Response [200]>

# %%
ria_page2 = rq.get(ria_nagasaki)
ria_page2
# Out:
# <Response [200]>

# %%
ria_page1.text
# Out:
# '<!DOCTYPE html><html lang="ru"><head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# article: http://ogp.me/ns/article# ya: http://webmaster.yandex.ru/vocabularies/"><meta http-equiv="Content-Type" content="text/html; charset=utf-8">\n            <!-- Google Tag Manager -->\n            <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push(\n            {\'gtm.start\': new Date().getTime(),event:\'gtm.js\'}\n            );var f=d.getElementsByTagName(s)[0],\n            j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n            \'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n            })(window,document,\'script\',\'dataLayer\',\'GTM-MGK7MGL\');</script>\n            <!-- End Google Tag Manager -->\n        <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js"></script><script>\n                  var googletag = googletag || {};\n                  googletag.cmd = googletag.cmd || [];\n 
# ...

# %%
ria_page2.text
# Out:
# '<!DOCTYPE html><html lang="ru"><head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# article: http://ogp.me/ns/article# ya: http://webmaster.yandex.ru/vocabularies/"><meta http-equiv="Content-Type" content="text/html; charset=utf-8">\n            <!-- Google Tag Manager -->\n            <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push(\n            {\'gtm.start\': new Date().getTime(),event:\'gtm.js\'}\n            );var f=d.getElementsByTagName(s)[0],\n            j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n            \'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n            })(window,document,\'script\',\'dataLayer\',\'GTM-MGK7MGL\');</script>\n            <!-- End Google Tag Manager -->\n        <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js"></script><script>\n                  var googletag = googletag || {};\n                  googletag.cmd = googletag.cmd || [];\n 
# ...

# %%
ria_soup1 = BeautifulSoup(ria_page1.text, 'html.parser') #сохраним результат в переменную soup

# %%
ria_soup2 = BeautifulSoup(ria_page2.text, 'html.parser') #сохраним результат в переменную soup

# %%
print(ria_soup1.prettify()) # показывает нашу страницу в красивом виде
# Out:
# <!DOCTYPE html>
# <html lang="ru">
#  <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# article: http://ogp.me/ns/article# ya: http://webmaster.yandex.ru/vocabularies/">
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <!-- Google Tag Manager -->
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push(
#             {'gtm.start': new Date().getTime(),event:'gtm.js'}
#             );var f=d.getElementsByTagName(s)[0],
#             j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#             'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#             })(window,document,'script','dataLayer','GTM-MGK7MGL');
#   </script>
#   <!-- End Google Tag Manager -->
#   <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js">
#   </script>
#   <script>
#    var googletag = googletag || {};
#                   googletag.cmd = googletag.cmd || [];
#   </script>
#   <script>
# ...

# %%
print(ria_soup2.prettify()) # показывает нашу страницу в красивом виде
# Out:
# <!DOCTYPE html>
# <html lang="ru">
#  <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# article: http://ogp.me/ns/article# ya: http://webmaster.yandex.ru/vocabularies/">
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <!-- Google Tag Manager -->
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push(
#             {'gtm.start': new Date().getTime(),event:'gtm.js'}
#             );var f=d.getElementsByTagName(s)[0],
#             j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#             'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#             })(window,document,'script','dataLayer','GTM-MGK7MGL');
#   </script>
#   <!-- End Google Tag Manager -->
#   <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js">
#   </script>
#   <script>
#    var googletag = googletag || {};
#                   googletag.cmd = googletag.cmd || [];
#   </script>
#   <script>
# ...

# %%
ria_soup1.find_all('a')
# Out:
# [<a class="header__sticked-link-home" href="/"></a>,
#  <a class="header__sticked-link-ria" href="https://ria.ru/"></a>,
#  <a class="header__menu-button header__menu-login" data-modal-open="authorization"><span class="header__menu-icon-l"><svg class="svg-icon"><use xlink:href="#header_icon-userL" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg></span><span class="header__menu-icon-s"><svg class="svg-icon"><use xlink:href="#header_icon-userS" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg></span></a>,
#  <a class="header__menu-button header__menu-search" data-modal-open="search"><span class="header__menu-icon-l"><svg class="svg-icon"><use xlink:href="#header_icon-searchL" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg></span><span class="header__menu-icon-s"><svg class="svg-icon"><use xlink:href="#header_icon-searchS" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg></span></a>,
# ...

# %%
ria_soup2.find_all('a')
# Out:
# [<a class="header__sticked-link-home" href="/"></a>,
#  <a class="header__sticked-link-ria" href="https://ria.ru/"></a>,
#  <a class="header__menu-button header__menu-login" data-modal-open="authorization"><span class="header__menu-icon-l"><svg class="svg-icon"><use xlink:href="#header_icon-userL" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg></span><span class="header__menu-icon-s"><svg class="svg-icon"><use xlink:href="#header_icon-userS" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg></span></a>,
#  <a class="header__menu-button header__menu-search" data-modal-open="search"><span class="header__menu-icon-l"><svg class="svg-icon"><use xlink:href="#header_icon-searchL" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg></span><span class="header__menu-icon-s"><svg class="svg-icon"><use xlink:href="#header_icon-searchS" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg></span></a>,
# ...

# %%
ria_soup1.find_all('a') [7]
# Out:
# <a class="list-item__title color-font-hover-only" href="https://ria.ru/20200117/1563526437.html">Японский суд запретил работу третьего блока АЭС "Иката", сообщает СМИ </a>

# %%
ria_soup2.find_all('a') [12]
# Out:
# <a class="list-item__image" href="https://ria.ru/20191128/1561708793.html"><picture><source media="(min-width: 480px)" media-type="ar16x9" srcset="https://cdn22.img.ria.ru/images/156170/95/1561709570_0:0:1281:720_436x0_80_0_0_80603d9d15c02f1200bfd39a0b25690c.jpg"/><source media="(min-width: 375px)" media-type="ar4x3" srcset="https://cdn22.img.ria.ru/images/156170/95/1561709570_143:0:1103:720_186x0_80_0_0_2dcfda9112b6d38145d24817dfe9e0a6.jpg"/><source media="(min-width: 0px)" media-type="ar1x1" srcset="https://cdn22.img.ria.ru/images/156170/95/1561709570_263:0:983:720_140x0_80_0_0_d2d85e556e020c9346e0c1c73b56bef6.jpg"/><img alt="Работа фотографа Джо О'Доннелла на выставке Плоды войны в Токио" class="responsive_img m-list-img" data-responsive0="https://cdn22.img.ria.ru/images/156170/95/1561709570_263:0:983:720_140x0_80_0_0_d2d85e556e020c9346e0c1c73b56bef6.jpg" data-responsive375="https://cdn22.img.ria.ru/images/156170/95/1561709570_143:0:1103:720_186x0_80_0_0_2dcfda9112b6d38145d24817df
# ...

# %%
ria_soup1.find_all('a') [7].get_text()
# Out:
# 'Японский суд запретил работу третьего блока АЭС "Иката", сообщает СМИ '

# %%
ria_soup2.find_all('a') [12].get_text()
# Out:
# 'Нагасаки (префектура)'

# %%
links = []
soup1list1 = ria_soup1.find_all('a')
#soup1list1

# %%
links = []
soup1list2 = ria_soup2.find_all('a')
#soup1list2

# %%
for elem in soup1list1: # для элемента списка
  links.append(elem.get_text()) # добавляем нужный атрибут(ссылку) в список для ссылок
links
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  'Санфречче ХиросимаКомандаФутбол',
#  '',
#  'Японский суд запретил работу третьего блока АЭС "Иката", сообщает СМИ ',
#  '',
#  'В Японии прокуратура провела обыск в офисе экс-министра юстиции ',
#  '',
#  'На волоске от смерти: горы атакуют человека  ',
#  'Ольга Бугроваобозреватель радио Sputnik',
#  'Хиросима (город)',
#  'Хиросима (префектура)',
#  '',
#  'На севере Хонсю произошло землетрясение магнитудой 5,5 ',
#  '',
#  'В Токио показали фото, из-за которого папа Римский приехал в Японию ',
#  '',
#  'Папа Римский Франциск встретился в Токио с императором Японии ',
#  '',
#  'В Хиросиме папа Римский Франциск осудил использование ядерного оружия ',
#  '',
#  'Папа Римский призвал мировых лидеров отказаться от ядерного оружия ',
#  '',
#  'Глава Южной Кореи попросил папу Римского встретиться с лидером КНДР ',
#  '',
#  'Папа Римский Франциск в Нагасаки призвал к миру без ядерного оружия ',
#  '',
# ...

# %%
for elem in soup1list2: # для элемента списка
  links.append(elem.get_text()) # добавляем нужный атрибут(ссылку) в список для ссылок
links

# %%
links_lower = []
for elem in links:
  elem = elem.lower()
  if elem != '':
    links_lower.append(elem)
links_lower
# Out:
# ['санфречче хиросимакомандафутбол',
#  'японский суд запретил работу третьего блока аэс "иката", сообщает сми ',
#  'в японии прокуратура провела обыск в офисе экс-министра юстиции ',
#  'на волоске от смерти: горы атакуют человека  ',
#  'ольга бугроваобозреватель радио sputnik',
#  'хиросима (город)',
#  'хиросима (префектура)',
#  'на севере хонсю произошло землетрясение магнитудой 5,5 ',
#  'в токио показали фото, из-за которого папа римский приехал в японию ',
#  'папа римский франциск встретился в токио с императором японии ',
#  'в хиросиме папа римский франциск осудил использование ядерного оружия ',
#  'папа римский призвал мировых лидеров отказаться от ядерного оружия ',
#  'глава южной кореи попросил папу римского встретиться с лидером кндр ',
#  'папа римский франциск в нагасаки призвал к миру без ядерного оружия ',
#  'папа римский франциск начал свой первый визит в японию ',
#  'маас выступил против вывода ядерного оружия сша из германии ',
# ...

# %%
for elem in links_lower:
  if "\n" in elem:
    elem = re.sub("\n","",elem)
    links_lower.append(elem)
links_lower
# Out:
# ['санфречче хиросимакомандафутбол',
#  'японский суд запретил работу третьего блока аэс "иката", сообщает сми ',
#  'в японии прокуратура провела обыск в офисе экс-министра юстиции ',
#  'на волоске от смерти: горы атакуют человека  ',
#  'ольга бугроваобозреватель радио sputnik',
#  'хиросима (город)',
#  'хиросима (префектура)',
#  'на севере хонсю произошло землетрясение магнитудой 5,5 ',
#  'в токио показали фото, из-за которого папа римский приехал в японию ',
#  'папа римский франциск встретился в токио с императором японии ',
#  'в хиросиме папа римский франциск осудил использование ядерного оружия ',
#  'папа римский призвал мировых лидеров отказаться от ядерного оружия ',
#  'глава южной кореи попросил папу римского встретиться с лидером кндр ',
#  'папа римский франциск в нагасаки призвал к миру без ядерного оружия ',
#  'папа римский франциск начал свой первый визит в японию ',
#  'маас выступил против вывода ядерного оружия сша из германии ',
# ...

# %%
ria_hiroshima = """'санфречче хиросимакомандафутбол',
 'японский суд запретил работу третьего блока аэс "иката", сообщает сми ',
 'в японии прокуратура провела обыск в офисе экс-министра юстиции ',
 'на волоске от смерти: горы атакуют человека  ',
 'ольга бугроваобозреватель радио sputnik',
 'хиросима (город)',
 'хиросима (префектура)',
 'на севере хонсю произошло землетрясение магнитудой 5,5 ',
 'в токио показали фото, из-за которого папа римский приехал в японию ',
 'папа римский франциск встретился в токио с императором японии ',
 'в хиросиме папа римский франциск осудил использование ядерного оружия ',
 'папа римский призвал мировых лидеров отказаться от ядерного оружия ',
 'глава южной кореи попросил папу римского встретиться с лидером кндр ',
 'папа римский франциск в нагасаки призвал к миру без ядерного оружия ',
 'папа римский франциск начал свой первый визит в японию ',
 'маас выступил против вывода ядерного оружия сша из германии ',
 '"тайна сферического студня раскрыта". океан преподнес удивительные находки ',
 '"санин" и "купание красного коня" как предзнаменование катастрофы ',
 'владимир бычковобозреватель радио sputnik',
 'игры и токио: флэшбеки из 1964-го за год до олимпиады ',
 'владимир спиваков: я разлюбил работать с иностранными оркестрами ',
 'волейболисты сборной японии победили канаду в заключительном матче км ',
 'тренер: игроки сборной россии не теряли концентрацию в матче с тунисцами ',
 'сборная россии завершила выступление на кубке мира победой над тунисцами ',
 'волейболисты сборной бразилии стали победителями кубка мира, обыграв японию '"""

# %%
from collections import defaultdict as dd
from operator import itemgetter

# %%
# wordcloud stuff

import matplotlib.pyplot as plt
from wordcloud import WordCloud

def show_wordcloud_by_freq_dict(freq_dict):
    wordcloud = WordCloud()
    wordcloud.generate_from_frequencies(frequencies=freq_dict)
    plt.figure()
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis("off")
    plt.show()

# %%
text_words_frequencies = dd(int) # это копируем
        
ria_hiroshima_tokenized = ria_hiroshima.split() # вместо название переменной где лежит текст
for word in ria_hiroshima_tokenized:
  text_words_frequencies[word] += 1 / len(ria_hiroshima_tokenized)

sorted_frequency_table = sorted(text_words_frequencies.items(), 
                                        key=itemgetter(1), reverse=True)    
        
for word, freq in sorted_frequency_table[:10]:
  print('\t'.join((word, str(freq))))
        
show_wordcloud_by_freq_dict(text_words_frequencies)
print(ria_hiroshima)
# Out:
# ',	0.08755760368663591
# в	0.03225806451612903
# римский	0.027649769585253458
# 'папа	0.018433179723502304
# франциск	0.018433179723502304
# с	0.018433179723502304
# ядерного	0.018433179723502304
# оружия	0.018433179723502304
# 'в	0.013824884792626727
# японии	0.013824884792626727
# 'санфречче хиросимакомандафутбол',
#  'японский суд запретил работу третьего блока аэс "иката", сообщает сми ',
#  'в японии прокуратура провела обыск в офисе экс-министра юстиции ',
#  'на волоске от смерти: горы атакуют человека  ',
#  'ольга бугроваобозреватель радио sputnik',
#  'хиросима (город)',
#  'хиросима (префектура)',
#  'на севере хонсю произошло землетрясение магнитудой 5,5 ',
#  'в токио показали фото, из-за которого папа римский приехал в японию ',
#  'папа римский франциск встретился в токио с императором японии ',
#  'в хиросиме папа римский франциск осудил использование ядерного оружия ',
#  'папа римский призвал мировых лидеров отказаться от ядерного оружия ',
# ...
