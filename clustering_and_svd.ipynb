# %% [markdown]
# <a href="https://colab.research.google.com/github/Uliana-san/Japan/blob/master/clustering_and_svd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Кластеризация

# %%
import re
import numpy as np
import pandas as pd
from nltk import word_tokenize
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ### Данные
#
# Новости: https://drive.google.com/open?id=12adiAGpoIwNJWffJIIE78-e3t1G5j5d8
#
# События: https://drive.google.com/open?id=121UUDI_UvzzU1s7SG21k2ltpJAUEVIhv

# %%
# для колаба:
# 1. запускаете эту ячейку
# 2. ждёте
# 3. внизу появляется кнопка с загрузкой с компьютера
# 4. выбираете файл на компьютере и загружаете
# 5. доооолго ждёте, пока` он скачается -_-
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-be0cc6b5-6173-406c-8865-2456626fb87e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-be0cc6b5-6173-406c-8865-2456626fb87e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving bible_vs_coding (3) 2.csv to bible_vs_coding (3) 2.csv

# %%
# !head raw_news.csv
# Out:
# id;event_id;text
# 0;1;"В ПЕТЕРБУРГЕ ПРОШЕЛ МИТИНГ ПРОТИВ ПЕРЕДАЧИ ИСААКИЕВСКОГО СОБОРА РПЦ В Санкт-Петербурге люди устроили акцию протеста против передачи Исаакиевского собора в безвозмездное пользование РПЦ. Жители Петербурга собрались на Исаакиевской площади, чтобы высказаться против передачи Исаакиевского собора в безвозмездное пользование РПЦ, передает ТАСС. Акция проходит в формате встречи с депутатами Законодательного собрания города и не требует согласования с властями. Участники акции не используют какую-либо символику и плакаты, а также мегафоны или средства звукоусиления. По словам депутата Алексея Ковалева, на Исаакиевскую площадь пришло примерно тысяча человек. Перед участниками протеста выступили депутаты местного парламента Борис Вишневский и Максим Резник, которые заявили о том, что потребуют отмены решения Смольного. Вишневский сообщил, что акция будет проходить в виде встречи депутатов с избирателями. ""Закон Санкт-Петербурга предоставляет нам право встречаться с избирателями, такую встречу мы и проведем, расскажем, как защищаем их интересы при передаче собора"", - сказал парламентарий. В свою очередь директор музея ""Исаакиевский собор"" Николай Буров проинформировал, что собор в пятницу будет закрыт намного раньше в связи с акцией протеста. Он подчеркнул, что необходимо избежать стычек между сторонниками передачи собора и ее противниками. Ранее стало известно, что собор передадут в безвозмездное пользование на 49 лет Русской православной церкви в лице Московского патриархата, при этом он останется в собственности Петербурга. Тем временем, в Петербурге продолжается сбор подписей под петицией об отмене данного решения, под документом уже поставили подписи более 160 тысяч человек. Комментарии Другие интересные статьи: http://kontrastniy.ru/obshchestvo/838-v-peterburge-proshel-miting-protiv-peredachi-isaakievskogo-sobora-rpts.html"
# 1;1;"Lenta.co, Москва, 14 января 2017 СИТУАЦИЯ С ПЕРЕДАЧЕЙ ИСААКИЕВСКОГО СОБОРА В ВЕДЕНИЕ РПЦ. ИСТОРИЯ СОБОРА Читать оригинал публикации на tvkultura.ru Ссылка на видео: https://player.vgtrk.com/iframe/video/id/1618844/start_zoom/true/showZoomBtn/false/sid/kultura/ Считать храмом Исаакиевский собор, невероятное творение Огюста Монферрана, будет отныне больше оснований. Губернатор Петербурга и Патриарх Московский и всея Руси договорились о том, что собор, принадлежащий городу, будет передан Русской православной церкви. Об этом губернатор Георгий Полтавченко сообщил в начале этой недели. Разговоры о передаче собора РПЦ шли давно, но эта новость все равно произвела сильный эффект. Пара сотен противников решения даже вышла вчера на митинг у собора, а чуть поодаль в
пример с Охта-центром, когда, по мнению многих, ситуация тоже была абсолютно безнадежной, и тем не менее, она разрешилась в интересах города. И я думаю, что это может быть символом того, что наши усилия не напрасны. В любом случае, нужно действовать, и тогда на вопрос, ""а что ты сделал, чтобы этого не произошло?"", каждый из нас сможет ответить: ""я сделал все, что мог"""". При этом Резник подчеркивает, что вопрос о принадлежности Исаакиевского собора - не политический и никак не связан с отношением того или иного горожанина к властям, к статусу Крыма, войне в Сирии и другим знакомым событиям. ""И если все петербуржцы, несмотря на возможные разногласия по другим вопросам, в той или иной форме заявят свою позицию по Исаакию, я уверен, что мы сможем его отстоять"", - считает политик. Максим Резник добавил, что собор приносит городу значительный доход именно в качестве одного из самых посещаемых туристических объектов. Лишь в прошлом году здесь побывали 3,9 млн российских и зарубежных туристов. ""И это лишний раз подтверждает тот тезис, что ситуация развивается не в правовой плоскости и не в религиозной. Этот вопрос - сугубо финансовый. И сегодня те, кто выступает за передачу собора от города к одной из религиозных конфессий, озабочены исключительно стяжательством"", - считает председатель комиссии по образованию, культуре и науке Городского Законодательного собрания Санкт-Петербурга Максим Резник. От серебряных рублей к ""деревянным"" Директор государственного бюджетного учреждения культуры ""Государственный музей-памятник ""Исаакиевский собор"""", народный артист Российской Федерации Николай Буров сообщил, что на реставрацию храма ежегодно затрачивалось не менее 100 миллионов рублей. ""Мы сейчас повторяем реставрационные работы, проведенные в послевоенное время, и гарантия сейчас будет на значительно более время, чем давалась нашими предшественниками"", - отметил Буров в беседе с корреспондентом ""Голоса Америки"". В целом же, собор тратит на восстановительные работы не менее половины своего бюджета. А бюджет год от года значительно меняется. Директор музея памятника свидетельствует: ""В 200 ...

# %% [markdown]
# ### Предобработка

# %%
,# Загрузили данные
df_events = pd.read_csv('events.csv', sep = ';')
df_news = pd.read_csv('raw_news.csv', index_col='id', sep = ';')

# %%
df_events
# Out:
#     id               date                                               name
# 0    1  01/10/17 12:00 AM  Власти Петербурга согласились передать РПЦ Иса...
# 1    2  01/20/17 12:00 AM  Дональд Трамп вступил в должность президента США.
# 2    3  02/20/17 12:00 AM  Скоропостижно скончался постпред России при ОО...
# 3    4  03/02/17 12:00 AM           Вышел фильм Навального «он Вам не димон»
# 4    5  03/14/17 12:00 AM  CNN показала фильм «Владимир Путин — самый вли...
# 5    6  03/21/17 12:00 AM                               Умер Дэвид рокфеллер
# 6    7  03/22/17 12:00 AM                  теракт произошел в центре Лондона
# 7    8  03/22/17 12:00 AM   Юлию Самойлову не пустили на евровидении в Киеве
# 8    9  03/23/17 12:00 AM  В центре Киева был убит бывший депутат Госдумы...
# 9   10  03/26/17 12:00 AM                   Митинг в москве против коррупции
# 10  11  03/31/17 12:00 AM  SpaceX впервые в истории запустила и посадила ...
# 11  12  04/01/17 12:00 AM                             Умер Евгений Евтушенко
# 12  13  04/12/17 12:00 AM  Тиллерсон посещает Москву и встречается с Путиным
# 13  14  04/19/17 12:00 AM  Премьер Медведев выступает перед депутатами Го...
# 14  15  04/29/17 12:00 AM          Несанкционированные акции в Москве апрель
# 15  16  05/02/17 12:00 AM                             Путин и Меркель в Сочи
# 16  17  05/05/17 12:00 AM                           Чемпионат мира по хоккею
# 17  18  05/06/17 12:00 AM  Правительство внесло в Госдуму законопроект о ...
# 18  19  05/08/17 12:00 AM                          Победа Макрона во Франции
# 19  20  05/14/17 12:00 AM                   Митинг против Реновации в Москве
# 20  21  05/29/17 12:00 AM                                    Ураган в Москве
# 21  22  06/10/17 12:00 AM              Парламентские выборы в Великобритании
# 22  23  06/12/17 12:00 AM                             Акции протеста 12 июня
# 23  24  06/15/17 12:00 AM                    Горячая линия Президента Путина
# 24  25  06/17/17 12:00 AM                            Кубок конфедерации FiFA
# 25  26  07/08/17 12:00 AM                                         Саммит G20
# 26  27  08/17/17 12:00 AM                                 Теракт в Барселоне
# 27  28  09/10/17 12:00 AM                            Единый день голосования

# %%
df_news
# Out:
#       event_id                                               text
# id
# 0            1  В ПЕТЕРБУРГЕ ПРОШЕЛ МИТИНГ ПРОТИВ ПЕРЕДАЧИ ИСА...
# 1            1  Lenta.co, Москва, 14 января 2017 СИТУАЦИЯ С ПЕ...
# 2            1  Аргументы и Факты (aif.ru), Москва, 14 января ...
# 3            1  Google Новости ТОП, Москва, 14 января 2017 АКЦ...
# 4            1  Газета.Ru, Москва, 13 января 2017 В МОСКОВСКОЙ...
# ...        ...                                                ...
# 1925        28  Lenta.Ru, Москва, 10 сентября 2017 КАНДИДАТ В ...
# 1926        28  Lenta.Ru, Москва, 10 сентября 2017 В ИЗБИРКОМА...
# 1927        28  Lenta.Ru, Москва, 10 сентября 2017 КАНДИДАТ В ...
# 1928        28  Lenta.Ru, Москва, 10 сентября 2017 МЕДВЕДЕВ ПР...
# 1929        28  Lenta.Ru, Москва, 10 сентября 2017 ЖИРИНОВСКИЙ...
#
# [1930 rows x 2 columns]

# %% [markdown]
# Посмотрим на данные:

# %%
print(df_news[df_news['event_id'] == 14].iloc[1].text)
# Out:
# Вести.ru, Москва, 19 апреля 2017 МЕДВЕДЕВ: НАЛОГИ В 2017 ГОДУ ПОВЫШАТЬСЯ НЕ БУДУТ В 2017 году налоги повышаться не будут, заверил депутатов Госдумы премьер-министр России Дмитрий Медведев. Он напомнил, что решение о стабильности налоговой системы было принято несколько лет назад. Кроме того, правительство продолжает выполнять установки президентских майских указов по повышению зарплат работникам образования, культуры и медицины. "Экономическая ситуация последних лет сказалась на доходах людей негативно, зарплаты в стране невысокие. Мы предпринимаем усилия для того, чтобы ситуацию выправить, ищем дополнительные ресурсы, чтобы помочь тем, кто зарабатывает мало", - отметил Медведев, выступая с отчетом о работе российского правительства за 2016 год в Думе. Дмитрий Медведев попросил депутатов и регионы активнее участвовать в работе по повышению зарплат работников этих сфер. Кроме того, правительство регулярно повышает минимальный размер оплаты труда, напомнил Медведев. В 2016 году он достиг 7500 рублей, с 1 июля 2017 года будет повышен до 7800 рублей, а в ближайшие несколько лет - до уровня прожиточного минимума работающего. Кроме того, правительство предусмотрело средства на повышение доступности и качества социальных услуг для пенсионеров в 2017 году. Сегодня каждый четвертый в России - пенсионер, напоминал глава российского правительства. При этом Медведев считает, что система поддержки, социальная инфраструктура, обслуживающая пожилых людей, устарела, ее надо серьезно менять. " И мы это уже делаем ", - оптимистично заявил Дмитрий Медведев. Отчет Дмитрия Медведев о работе правительства в 2016 году в Госдуме в прямом эфире транслируют сайт Вести.Ru и телеканал "Россия 24". http://www.vesti.ru/doc.html?id=2879350

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# Загрузили стопслова для русского языка из nltk
stopset = stopwords.words('russian')
stopset[:10]
# Out:
# ['и', 'в', 'во', 'не', 'что', 'он', 'на', 'я', 'с', 'со']

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# Токенизация, чистка
def tokenize(msg):
    # убрали знаки препинания и привели к нижнему регистру
    msg = re.sub('[!"?/\\().:;,-]', '', msg).lower()
    msg = [w for w in word_tokenize(msg) if not w in stopset] # токенизировали и избавились от стоп слов
    return msg

# %%
tokenize(df_news['text'].iloc[0])[:10]
# Out:
# ['петербурге',
#  'прошел',
#  'митинг',
#  'против',
#  'передачи',
#  'исаакиевского',
#  'собора',
#  'рпц',
#  'санктпетербурге',
#  'люди']

# %% [markdown]
# Посмотрим на распоределение данных по событиям:

# %%
sns.countplot(x=df_news['event_id'], data=df_news, palette="Set3")

# %% [markdown]
# Из представленного выше графика видно, что данные неоднородны.

# %% [markdown]
# ## Часть 2. Кластеризация текстов

# %% [markdown]
# **Задача**: Кластеризовать новости и проверить, получается ли восстановить кластерную структуру новостей, то есть, разделить их на 28 кластеров, соответствущих событиям.

# %% [markdown]
# ### Строим k-means модель на tf-idf

# %% [markdown]
# В этом разделе мы применим один из методов кластеризации с использованием tf-idf и метода k-means.

# %% [markdown]
# #### Tf-idf преобразование

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# Преобразовываем документы в векторы с tf-idf.

# %%
bow_tfidf = TfidfVectorizer(tokenizer=tokenize)
bowed_news = bow_tfidf.fit_transform(df_news['text'])

# %%
bowed_news
# Out:
# <1930x65180 sparse matrix of type '<class 'numpy.float64'>'
# 	with 509127 stored elements in Compressed Sparse Row format>

# %% [markdown]
# #### K-means кластериазация

# %%
from sklearn.cluster import KMeans

# %%
model = KMeans(n_clusters=28, init='k-means++', max_iter=100, n_init=1, random_state=37)
model.fit(bowed_news)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=100,
#        n_clusters=28, n_init=1, n_jobs=None, precompute_distances='auto',
#        random_state=37, tol=0.0001, verbose=0)

# %% [markdown]
# Чтобы примерно оценить темы новостных кластеров, выведем для каждого из них топ 10 слов, характерных для каждого кластера:

# %%
len(model.cluster_centers_)
# Out:
# 28

# %%
print("Top terms per cluster:")
order_centroids = model.cluster_centers_.argsort()[:, ::-1] # индексы слов, по мере убывания близости к центру
terms = bow_tfidf.get_feature_names() # массив слов в том порядке, в котором их помнит kmeans
for i in range(28):
    print("Cluster %d:" % i),
    for ind in order_centroids[i, :10]: # печатаем 10 самых близких
        print(terms[ind])
    print()
# Out:
# Top terms per cluster:
# Cluster 0:
# сборной
# сборная
# мира
# хоккею
# матче
# мая
# чемпионата
# команды
# этапа
# группового
#
# Cluster 1:
# %
# голосования
# d0
# выборы
# явка
# выборах
# сентября
# избирателей
# области
# 10
#
# Cluster 2:
# путин
# это
# президент
# вопрос
# сша
# лавров
# россии
# тиллерсон
# евровидение
# вопросы
#
# Cluster 3:
# мандатов
# великобритании
# 318
# консерваторов
# партии
# лейбористской
# 262
# окончательные
# партия
# юнионистской
#
# Cluster 4:
# акции
# навального
# навальный
# протеста
# москве
# митинг
# тверской
# июня
# митинга
# человек
#
# Cluster 5:
# барселоне
# риа
# барселоны
# новости
# камбрильсе
# испании
# каталонии
# >
# людей
# фургон
#
# Cluster 6:
# собора
# рпц
# исаакиевского
# передачи
# собор
# января
# исаакиевский
# церкви
# акция
# против
#
# Cluster 7:
# доволен
# остался
# трампом
# путин
# песков
# встречей
# первой
# трампа
# июля
# гамбурге
#
# Cluster 8:
# трамп
# сша
# трампа
# псаки
# путина
# выборы
# инаугурация
# дональд
# президента
# g20
#
# Cluster 9:
# урагана
# москве
# человек
# погибших
# мая
# ураган
# деревьев
# 30
# стихии
# подмосковье
#
# Cluster 10:
# falcon
# 9
# ракеты
# spacex
# запуск
# ступень
# space
# x
# маска
# компании
#
# Cluster 11:
# вороненков
# вороненкова
# денис
# убит
# госдумы
# дениса
# украины
# киеве
# киева
# убийство
#
# Cluster 12:
# медведева
# фбк
# расследование
# фонд
# навального
# медведев
# фонда
# димон
# дар
# расследования
#
# Cluster 13:
# путин
# президент
# прямой
# линии
# вопрос
# линия
# прямая
# сказал
# цифровой
# сказать
#
# Cluster 14:
# конфедераций
# кубка
# fifa
# июня
# кубок
# матч
# 19
# казани
# матча
# 17
#
# Cluster 15:
# евтушенко
# евгений
# поэт
# поэта
# умер
# апреля
# сша
# жизни
# моргулис
# евгения
#
# Cluster 16:
# меркель
# порошенко
# сочи
# путин
# канцлер
# германии
# украине
# путина
# фрг
# ангела
#
# Cluster 17:
# оон
# чуркине
# чуркин
# цветы
# виталии
# февраля
# мид
# свечи
# лист
# бумаги
#
# Cluster 18:
# сбор
# сбора
# курортный
# курортного
# курортной
# законопроект
# эксперимента
# рублей
# инфраструктуры
# туристов
#
# Cluster 19:
# партия
# мандатов
# великобритании
# выборов
# июня
# парламентских
# партии
# юнионистская
# либералдемократическая
# результаты
#
# Cluster 20:
# евтушенко
# евгений
# поэт
# году
# поэта
# умер
# александрович
# жизни
# апреля
# стихи
#
# Cluster 21:
# митинга
# навального
# коррупции
# суд
# поедет
# марта
# суток
# суда
# митинг
# тысяч
#
# Cluster 22:
# мэй
# великобритании
# партия
# выборов
# трамп
# мест
# парламентских
# парламенте
# консерваторы
# июня
#
# Cluster 23:
# лондоне
# теракт
# теракта
# марта
# мэй
# парламента
# 23
# великобритании
# мосту
# террорист
#
# Cluster 24:
# рокфеллер
# дэвид
# умер
# рокфеллера
# миллиардер
# 101
# года
# миллиардера
# возрасте
# ньюйорке
#
# Cluster 25:
# эксперимента
# сбора
# законопроект
# госдуму
# курортной
# курортного
# алтайском
# ставропольском
# внесло
# сборе
#
# Cluster 26:
# франции
# макрона
# макрон
# пен
# ле
# %
# победой
# марин
# туре
# победу
#
# Cluster 27:
# чуркин
# виталий
# оон
# чуркина
# февраля
# смерти
# умер
# виталия
# причина
# ньюйорке

# %% [markdown]
# По субъективным ощущениям от характерных терминов, новости кластеризовались хорошо.

# %% [markdown]
# ### Оценки

# %%
from sklearn.metrics import adjusted_rand_score, homogeneity_score, completeness_score, v_measure_score

# %%
labels = df_news.event_id # истинные метки событий
clust_labels = model.labels_ # метки номеров кластеров, возвращённых алгортмом

# %% [markdown]
# Суть метрик качества и их значение для модели с дефолтными настройками. В следующем разделе мы попробуем другие модели и пытаемся проинтерпретировать результаты.

# %% [markdown]
# Меряем Adjusted Rand Index.
#
# **Rand Index (RI)** выражает схожесть двух разных кластеризаций одной и той же выборки. Пусть n — число объектов в выборке, a — число пар объектов, имеющих одинаковые метки и находящихся в одном кластере, b — число пар объектов, имеющих различные метки и находящихся в разных кластерах.
#
# $$RI = \frac{2(a + b)}{n(n - 1)}$$
#
# Это доля объектов, для которых эти разбиения (исходное и полученное в результате кластеризации) "согласованы". Эта мера не зависит от значений и перестановок меток.
#
# **Adjusted Rand Index** — это Rand Index, нормированный, чтобы он давал значения близкие к нулю для случайных кластеризаций при любом n и числе кластеров:
#
# $$ARI = \frac{RI - E[RI]}{max(RI)-E[RI]}$$
#
# (Теория взята из статьи на хабрахабр: https://habrahabr.ru/company/ods/blog/325654/)

# %%
print("Adjusted Rand-Index:",  adjusted_rand_score(labels, clust_labels))
# Out:
# Adjusted Rand-Index: 0.7570416601743547

# %% [markdown]
# Меряем гомогенность, полноту и V-меру.
#
# Пусть K — результат кластеризации, C — истинное разбиение выборки на классы. Гомогенность h и полнота с определяются с использованием функций энтропии и условной энтропии:
#
# $$h = 1 - \frac{H(C|K)}{H(C)}\text{, }c = 1 - \frac{H(K|C)}{H(K)}$$
#
# V-мера -- это среднее гармоическое от h и c.
#
# Так как данные метрики дают более точный результат при маленьком количестве кластеров, мы будем в большей мере ориентироваться на ARI.
# ([Хорошее объяснение](https://www.geeksforgeeks.org/ml-v-measure-for-evaluating-clustering-performance/))

# %%
print("Гомогенность:", homogeneity_score(labels, clust_labels))
print("Полнота:", completeness_score(labels, clust_labels))
print("V-мера",  v_measure_score(labels, clust_labels))
# Out:
# Гомогенность: 0.8875253007837167
# Полнота: 0.8856558524903907
# V-мера 0.8865895911661348

# %% [markdown]
# Как мы видим, новости довольно хорошо разбиваются на кластеры в конфигурации tf-idf + k-means.

# %% [markdown]
# ### Альтернативные модели
#
# А теперь давайте поизменяем гиперпараметры и попробуем другие алгоритмы. Станет ли лучше?

# %%
from sklearn.cluster import DBSCAN

# %%
clust = DBSCAN()
clust.fit(bowed_news)
# Out:
# DBSCAN(algorithm='auto', eps=0.5, leaf_size=30, metric='euclidean',
#     metric_params=None, min_samples=5, n_jobs=1, p=None)

# %%
dbscan_labels = clust.labels_

# %%
print("Adjusted Rand-Index:",  adjusted_rand_score(labels, dbscan_labels))
# Out:
# Adjusted Rand-Index: 0.00311585345097457

# %%
print("Гомогенность:", homogeneity_score(labels, dbscan_labels))
print("Полнота:", completeness_score(labels, dbscan_labels))
print("V-мера",  v_measure_score(labels, dbscan_labels))
# Out:
# Гомогенность: 0.0730500897149184
# Полнота: 0.49006413668830046
# V-мера 0.12714730856581233

# %% [markdown]
# Вернёмся к кластеризации:

# %%
model = KMeans(n_clusters=7, init='k-means++', max_iter=100, n_init=1, random_state=37)
model.fit(bowed_news)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=100,
#     n_clusters=7, n_init=1, n_jobs=1, precompute_distances='auto',
#     random_state=37, tol=0.0001, verbose=0)

# %%
print("Top terms per cluster:")
order_centroids = model.cluster_centers_.argsort()[:, ::-1]
terms = bow_tfidf.get_feature_names()
for i in range(7):
    print("Cluster %d:" % i),
    for ind in order_centroids[i, :7]:
        print(' %s' % terms[ind]),
# Out:
# Top terms per cluster:
# Cluster 0:
#  лондоне
#  барселоне
#  теракт
#  теракта
#  риа
#  falcon
#  человек
# Cluster 1:
#  путин
#  меркель
#  сша
#  чуркин
#  трамп
#  президент
#  путина
# Cluster 2:
#  %
#  партия
#  великобритании
#  выборов
#  d0
#  мандатов
#  мэй
# Cluster 3:
#  евтушенко
#  акции
#  навального
#  собора
#  навальный
#  евгений
#  рпц
# Cluster 4:
#  урагана
#  москве
#  человек
#  погибших
#  мая
#  ураган
#  30
# Cluster 5:
#  голосования
#  %
#  выборы
#  явка
#  выборах
#  сентября
#  избирателей
# Cluster 6:
#  сбора
#  сбор
#  курортного
#  эксперимента
#  законопроект
#  курортный
#  курортной

# %% [markdown]
# # SVD
#
# Возмём задачу из позапрошлого семинара и добавим в представлние дркументов SVD.

# %%
lenta = pd.read_csv('news_lenta_cropped.csv')

# %%
lenta.head()
# Out:
#                                                title              topic
# 0  Грудь Бритни Спирс вновь выскочила из лифчика ...           Культура
# 1  Попытка вернуть укатившийся мяч у Кремлевской ...  Силовые структуры
# 2                      Хабенский стал врагом Украины           Культура
# 3             В Туркмении запретили продажу алкоголя        Бывший СССР
# 4  В Великобритании нашли утерянный сценарий Стен...           Культура

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression

# %%
vectorizer = CountVectorizer()
bow = vectorizer.fit_transform(lenta.title)

# %%
X_train, X_test, y_train, y_test = train_test_split(bow, lenta.topic)

# %%
clf = LogisticRegression()
clf.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, clf.predict(X_test)))
# Out:
#                    precision    recall  f1-score   support
#
#       Бывший СССР       0.96      0.96      0.96     12949
#          Культура       0.93      0.97      0.95     13162
# Силовые структуры       0.93      0.87      0.90      4644
#          Ценности       0.96      0.75      0.84      1728
#
#       avg / total       0.94      0.94      0.94     32483

# %% [markdown]
# Попробуем SVD:

# %%
from sklearn.decomposition import TruncatedSVD

# %%
svd = TruncatedSVD(n_components=100, n_iter=7, random_state=42)

# %%
svd.fit(bow)
# Out:
# TruncatedSVD(algorithm='randomized', n_components=100, n_iter=7,
#        random_state=42, tol=0.0)

# %%
bow_transformed = svd.transform(bow)

# %%
len(bow_transformed[0])
# Out:
# 300

# %% [markdown]
# Посмотрим, что он умеет:

# %%
a = svd.transform(vectorizer.transform(['президент приехал с визитом']))
b = svd.transform(vectorizer.transform(['президент приехал в москву']))
c = svd.transform(vectorizer.transform(['кот смотрит на картины']))

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
cosine_similarity(a, b)
# Out:
# array([[0.72361874]])

# %%
cosine_similarity(a, c)
# Out:
# array([[-0.00037305]])

# %%
at = vectorizer.transform(['президент приехал с визитом'])
bt = vectorizer.transform(['президент приехал в москву'])
ct = vectorizer.transform(['кот смотрит на картины'])

# %%
cosine_similarity(at, bt)
# Out:
# array([[0.66666667]])

# %%
cosine_similarity(at, ct)
# Out:
# array([[0.]])

# %%
X_train, X_test, y_train, y_test = train_test_split(bow_transformed, lenta.topic)

# %%
clf = LogisticRegression()
clf.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
print(classification_report(y_test, clf.predict(X_test)))
# Out:
#                    precision    recall  f1-score   support
#
#       Бывший СССР       0.83      0.78      0.81     12989
#          Культура       0.69      0.91      0.79     13133
# Силовые структуры       0.67      0.39      0.49      4622
#          Ценности       0.58      0.11      0.18      1739
#
#       avg / total       0.74      0.74      0.72     32483

# %% [markdown]
# **Задание**: попробуйте разное количество компонент в SVD.
